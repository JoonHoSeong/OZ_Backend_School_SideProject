# %%
from sqlalchemy import create_engine
from sqlalchemy import MetaData
from dummymaker_mysql.control_table import *
from dummymaker_mysql.dummy_generator import *
from sqlalchemy import inspect

# %%
engine = create_engine(f'mysql+pymysql://root:root@localhost:3306/airportdb?charset=utf8mb4', echo=True)
metadata = MetaData()
metadata.reflect(engine)
# Out:
# 2024-05-07 14:13:16,627 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-05-07 14:13:16,629 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 14:13:16,637 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-05-07 14:13:16,638 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 14:13:16,642 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-05-07 14:13:16,643 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 14:13:16,649 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-07 14:13:16,651 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `airportdb`
# 2024-05-07 14:13:16,652 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 14:13:16,661 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `airline`
# 2024-05-07 14:13:16,664 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 14:13:16,669 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `airplane`
# 2024-05-07 14:13:16,670 INFO sqlalchemy.engine.Engine [raw sql] {}
# ...

# %%
table_list = get_table_list(meta_data = metadata)

# %%
test = set()
for t in metadata.sorted_tables :
    print(t)
    for c in t.columns :
        print(c.name, c.type)
        print('\n\n\n\n\n')
        print(c.contains(''))
# Out:
# airline
# airline_id SMALLINT
#
#
#
#
#
#
# airline.airline_id LIKE '%' || :airline_id_1 || '%'
# iata CHAR(2) COLLATE "utf8mb4_unicode_ci"
#
#
#
#
#
#
# airline.iata LIKE '%' || :iata_1 || '%'
# airlinename VARCHAR(30) COLLATE "utf8mb4_unicode_ci"
#
#
#
#
#
#
# airline.airlinename LIKE '%' || :airlinename_1 || '%'
# base_airport SMALLINT
#
#
#
#
#
#
# airline.base_airport LIKE '%' || :base_airport_1 || '%'
# airplane
# airplane_id INTEGER
#
#
#
#
#
#
# airplane.airplane_id LIKE '%' || :airplane_id_1 || '%'
# capacity MEDIUMINT
#
#
#
#
#
#
# airplane.capacity LIKE '%' || :capacity_1 || '%'
# type_id INTEGER
#
#
#
#
#
#
# airplane.type_id LIKE '%' || :type_id_1 || '%'
# airline_id INTEGER
#
#
#
#
#
#
# airplane.airline_id LIKE '%' || :airline_id_1 || '%'
# airplane_type
# type_id INTEGER
#
#
#
#
#
#
# airplane_type.type_id LIKE '%' || :type_id_1 || '%'
# identifier VARCHAR(50) COLLATE "utf8mb4_unicode_ci"
#
#
#
#
#
#
# airplane_type.identifier LIKE '%' || :identifier_1 || '%'
# ...

# %%
c.type.column_property
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 c.type.column_property
#
# AttributeError: 'CHAR' object has no attribute 'column_property'

# %%
from sqlalchemy.engine.reflection import Inspector
inspector = Inspector.from_engine(engine)
for t in metadata.sorted_tables :
    # pk_constraint = inspector.get_pk_constraint(t.name)
    # print(pk_constraint['constrained_columns'][0])
    print(inspector.get_check_constraints(t.name))
    break
# Out:
# 2024-05-07 15:44:51,983 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-07 15:44:51,986 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `airline`
# 2024-05-07 15:44:51,987 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-07 15:44:51,992 INFO sqlalchemy.engine.Engine ROLLBACK
# []
# /var/folders/_0/sglhm_1s48z2d21krx9htrb40000gn/T/ipykernel_95095/751250228.py:2: SADeprecationWarning: The from_engine() method on Inspector is deprecated and will be removed in a future release.  Please use the sqlalchemy.inspect() function on an Engine or Connection in order to acquire an Inspector. (deprecated since: 1.4)
#   inspector = Inspector.from_engine(engine)

# %%
# Out:
# str
